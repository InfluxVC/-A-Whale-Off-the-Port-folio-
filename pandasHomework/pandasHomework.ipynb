# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %%
whale_ReturnsDF=pd.read_csv("whale_returns.csv")

# %%
whale_ReturnsDF.isna().sum()


54
# Out:
# 54

# %%
Whale_DF=whale_ReturnsDF.dropna()

# %%
Whale_DF.columns
# Out:
# Index(['Date', 'SOROS FUND MANAGEMENT LLC', 'PAULSON & CO.INC. ',
#        'TIGER GLOBAL MANAGEMENT LLC', 'BERKSHIRE HATHAWAY INC'],
#       dtype='object')

# %%
Whale_DF.sort_index()
# Out:
#             Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 1     2015-03-03                  -0.001266           -0.004981
# 2     2015-03-04                   0.002230            0.003241
# 3     2015-03-05                   0.004016            0.004076
# 4     2015-03-06                  -0.007905           -0.003574
# 5     2015-03-09                   0.000582            0.004225
# ...          ...                        ...                 ...
# 1055  2019-04-25                  -0.000285           -0.001291
# 1056  2019-04-26                   0.008149            0.009162
# 1057  2019-04-29                   0.001254            0.002719
# 1058  2019-04-30                  -0.001295           -0.002211
# 1059  2019-05-01                  -0.005847           -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 1                       -0.000496               -0.006569
# 2                       -0.002534                0.004213
# ...

# %%
Whale_DF["Date"].apply(lambda x: pd.to_datetime (x[0]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2053         try:
# -> 2054             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2055             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-479-3a55979cf10f> in <module>
# ----> 1 Whale_DF["Date"].apply(lambda x: pd.to_datetime (x[0]))
#
# ...

# %%
Whale_DF.dtypes
# Out:
# Date                            object
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# dtype: object

# %%
Whale_DF['Date']=pd.to_datetime(Whale_DF['Date'])
# Out:
# <ipython-input-24-82b6b46a9568>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Whale_DF['Date']=pd.to_datetime(Whale_DF['Date'])

# %%
Whale_DF["Date"].loc["Date"]="Date"
# Out:
# /Users/jupiter83/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
Algo_ReturnDF=pd.read_csv("algo_returns.csv")

# %%
Algo_ReturnDF.isna().sum()
# Out:
# Date      0
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
Algo_ReturnDF.dtypes
# Out:
# Date       object
# Algo 1    float64
# Algo 2    float64
# dtype: object

# %%
Algo_ReturnCDF=Algo_ReturnDF.dropna()

# %%
Algo_ReturnCDF.isna().any()
# Out:
# Date      False
# Algo 1    False
# Algo 2    False
# dtype: bool

# %%
Algo_ReturnCDF['Date']=pd.to_datetime(Algo_ReturnCDF['Date'])
# Out:
# <ipython-input-31-850429912bf4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Algo_ReturnCDF['Date']=pd.to_datetime(Algo_ReturnCDF['Date'])

# %%
Algo_ReturnCDF["Date"].loc["Date"]="Date"
# Out:
# /Users/jupiter83/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
Algo_ReturnCDF["Date"].apply(lambda x: pd.to_datetime (x[0]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-522-290deae33817> in <module>
# ----> 1 Algo_ReturnCDF["Date"].apply(lambda x: pd.to_datetime (x[0]))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-522-290deae33817> in <lambda>(x)
# ----> 1 Algo_ReturnCDF["Date"].apply(lambda x: pd.to_datetime (x[0]))
#
# TypeError: 'Timestamp' object is not subscriptable

# %%
Algo_ReturnCDF.dtypes
# Out:
# Date      datetime64[ns]
# Algo 1           float64
# Algo 2           float64
# dtype: object

# %%
SP_500DF=pd.read_csv("sp500_history.csv")

# %%
SP_500DF.rename(columns={'Close':'SP500'}, inplace=True)

# %%
SP_500DF.columns
# Out:
# Index(['Date', 'SP500'], dtype='object')

# %%
SP_500DF.isna().sum()
# Out:
# Date     0
# SP500    0
# dtype: int64

# %%
SP_500DF.dtypes
# Out:
# Date     object
# SP500    object
# dtype: object

# %%
SP_500DF
# Out:
#            Date     SP500
# 0     23-Apr-19  $2933.68
# 1     22-Apr-19  $2907.97
# 2     18-Apr-19  $2905.03
# 3     17-Apr-19  $2900.45
# 4     16-Apr-19  $2907.06
# ...         ...       ...
# 1644   5-Oct-12  $1460.93
# 1645   4-Oct-12  $1461.40
# 1646   3-Oct-12  $1450.99
# 1647   2-Oct-12  $1445.75
# 1648   1-Oct-12  $1444.49
#
# [1649 rows x 2 columns]

# %%
SP_500DF["Date"]=pd.to_datetime(SP_500DF["Date"])

# %%
SP_500DF["Date"]=SP_500DF["Date"].apply(lambda x: pd.to_datetime (x[0]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-a5e203f8e72b> in <module>
# ----> 1 SP_500DF["Date"]=SP_500DF["Date"].apply(lambda x: pd.to_datetime (x[0]))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-41-a5e203f8e72b> in <lambda>(x)
# ----> 1 SP_500DF["Date"]=SP_500DF["Date"].apply(lambda x: pd.to_datetime (x[0]))
#
# TypeError: 'Timestamp' object is not subscriptable

# %%
SP_500DF["SP500"]=SP_500DF["SP500"].str.replace("$","")

# %%
SP_500DF["SP500"]= SP_500DF.SP500.astype(float)

# %%
SP_500DF['SP500']=SP_500DF["SP500"].pct_change()

# %%
SP_500DF.rename(columns = {'SP500':'Daily_Price'})
# Out:
#            Date  Daily_Price
# 0    2019-04-23          NaN
# 1    2019-04-22    -0.008764
# 2    2019-04-18    -0.001011
# 3    2019-04-17    -0.001577
# 4    2019-04-16     0.002279
# ...         ...          ...
# 1644 2012-10-05     0.003469
# 1645 2012-10-04     0.000322
# 1646 2012-10-03    -0.007123
# 1647 2012-10-02    -0.003611
# 1648 2012-10-01    -0.000872
#
# [1649 rows x 2 columns]

# %%
SP_500DF.plot(x='Date')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ConcatDF_DF2.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-1cb3d0d61d0f> in <module>
# ----> 1 ConcatDF_DF2.dtypes
#
# NameError: name 'ConcatDF_DF2' is not defined

# %%
SP_500DF.dtypes
# Out:
# Date     datetime64[ns]
# SP500           float64
# dtype: object

# %%
ConcatDF_DF2["Date"]=ConcatDF_DF2["Date"].apply(lambda x: pd.to_datetime (x[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-805820cd4599> in <module>
# ----> 1 ConcatDF_DF2["Date"]=ConcatDF_DF2["Date"].apply(lambda x: pd.to_datetime (x[0]))
#
# NameError: name 'ConcatDF_DF2' is not defined

# %%
ConcatDF_DF2["Date"].astype('datetime')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-c640de87d549> in <module>
# ----> 1 ConcatDF_DF2["Date"].astype('datetime')
#
# NameError: name 'ConcatDF_DF2' is not defined

# %%
ConcatDF_DF2=pd.merge(Whale_DF,Algo_ReturnCDF,how= "inner", on='Date')

# %%
ConcatDF_DF3=pd.merge(SP_500DF,ConcatDF_DF2, how="inner",on='Date')

# %%
ConcatDF_DF3.head()
# Out:
#         Date     SP500  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0 2019-04-23       NaN                   0.007167            0.003485
# 1 2019-04-22 -0.008764                  -0.002586           -0.007333
# 2 2019-04-18 -0.001011                   0.001448            0.001222
# 3 2019-04-17 -0.001577                  -0.002897           -0.006467
# 4 2019-04-16  0.002279                   0.002699            0.000388
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1    Algo 2
# 0                     0.006472                0.013278  0.004969  0.009622
# 1                    -0.003640               -0.001088  0.000677 -0.001936
# 2                     0.000582                0.001916 -0.000588 -0.001229
# 3                    -0.004409                0.003222 -0.010301 -0.005228
# 4                    -0.000831                0.000837 -0.006945  0.002899

# %%
ConcatDF_DF3.isna().sum()
# Out:
# Date                           0
# SP500                          1
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# dtype: int64

# %%
ConcatDF_DF3.columns
# Out:
# Index(['Date', 'SP500', 'SOROS FUND MANAGEMENT LLC', 'PAULSON & CO.INC. ',
#        'TIGER GLOBAL MANAGEMENT LLC', 'BERKSHIRE HATHAWAY INC', 'Algo 1',
#        'Algo 2'],
#       dtype='object')

# %%
ConcatDF_DF3.plot(x='Date',kind='line')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Concat_STD=ConcatDF_DF3.std()
Concat_mean=ConcatDF_DF3.mean()
# Out:
# <ipython-input-57-553723e6bf6b>:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Concat_mean=ConcatDF_DF3.mean()

# %%
ConcatDF_DF3.max()
# Out:
# Date                           2019-04-23 00:00:00
# SP500                                    0.0427303
# SOROS FUND MANAGEMENT LLC                0.0429769
# PAULSON & CO.INC.                        0.0293381
# TIGER GLOBAL MANAGEMENT LLC              0.0807045
# BERKSHIRE HATHAWAY INC                   0.0613413
# Algo 1                                   0.0507353
# Algo 2                                   0.0308223
# dtype: object

# %%
ConcatDF_DF3.mean()
# Out:
# <ipython-input-59-7e9a2938e97a>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   ConcatDF_DF3.mean()
# SP500                         -0.000281
# SOROS FUND MANAGEMENT LLC      0.000177
# PAULSON & CO.INC.             -0.000214
# TIGER GLOBAL MANAGEMENT LLC   -0.000083
# BERKSHIRE HATHAWAY INC         0.000506
# Algo 1                         0.000662
# Algo 2                         0.000263
# dtype: float64

# %%
ConcatDF_DF3.pct_change
# Out:
# <bound method NDFrame.pct_change of            Date     SP500  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0    2019-04-23       NaN                   0.007167            0.003485
# 1    2019-04-22 -0.008764                  -0.002586           -0.007333
# 2    2019-04-18 -0.001011                   0.001448            0.001222
# 3    2019-04-17 -0.001577                  -0.002897           -0.006467
# 4    2019-04-16  0.002279                   0.002699            0.000388
# ...         ...       ...                        ...                 ...
# 1038 2015-03-09  0.017254                   0.000582            0.004225
# 1039 2015-03-06 -0.003929                  -0.007905           -0.003574
# 1040 2015-03-05  0.014378                   0.004016            0.004076
# 1041 2015-03-04 -0.001195                   0.002230            0.003241
# 1042 2015-03-03  0.004408                  -0.001266           -0.004981
#
# ...

# %%
ConcatDF_DF3.cumprod().plot(x='Date',kind='line')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Concat_STD_21.cumprod().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
SP500_CSTD=ConcatDF_DF3['SP500'].std()
SP500_Var=ConcatDF_DF3['SP500'].var()

# %%
ConcatDF_DF3.plot(x='Date',kind='box' )
# Out:
# <AxesSubplot:>

# %%
SP500_CSTD
# Out:
# 0.008586889747073993

# %%
ConcatDF_DF3
# Out:
#            Date     SP500  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0    2019-04-23       NaN                   0.007167            0.003485
# 1    2019-04-22 -0.008764                  -0.002586           -0.007333
# 2    2019-04-18 -0.001011                   0.001448            0.001222
# 3    2019-04-17 -0.001577                  -0.002897           -0.006467
# 4    2019-04-16  0.002279                   0.002699            0.000388
# ...         ...       ...                        ...                 ...
# 1038 2015-03-09  0.017254                   0.000582            0.004225
# 1039 2015-03-06 -0.003929                  -0.007905           -0.003574
# 1040 2015-03-05  0.014378                   0.004016            0.004076
# 1041 2015-03-04 -0.001195                   0.002230            0.003241
# 1042 2015-03-03  0.004408                  -0.001266           -0.004981
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1    Algo 2
# ...

# %%
Concat_STD_21 = ConcatDF_DF3.rolling(window=21).std()
Concat_STD_60 = ConcatDF_DF3.rolling(window=60).std()
Concat_STD_252 = ConcatDF_DF3.rolling(window=252).std()

# %%
Concat_STD_21.plot()
# Out:
# <AxesSubplot:>

# %%
Concat_STD_21.columns
# Out:
# Index(['SP500', 'SOROS FUND MANAGEMENT LLC', 'PAULSON & CO.INC. ',
#        'TIGER GLOBAL MANAGEMENT LLC', 'BERKSHIRE HATHAWAY INC', 'Algo 1',
#        'Algo 2'],
#       dtype='object')

# %%
Concat_STD_21.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
Concat_STD_60.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
Concat_STD_252.plot()
# Out:
# <AxesSubplot:>

# %%
Concat_Corr=ConcatDF_DF3.corr()

# %%
Concat_Corr.plot()
# Out:
# <AxesSubplot:>

# %%
Concat_Var=ConcatDF_DF3.var()

# %%
Concat_Var.plot()
# Out:
# <AxesSubplot:>

# %%
Whale_CV=Whale_DF.cov()

# %%
# Out:
# Index(['Date', 'SOROS FUND MANAGEMENT LLC', 'PAULSON & CO.INC. ',
#        'TIGER GLOBAL MANAGEMENT LLC', 'BERKSHIRE HATHAWAY INC'],
#       dtype='object')

# %%
Beta_WCV=Whale_CV / Concat_Var

# %%
Beta_WCV.plot()
# Out:
# <AxesSubplot:>

# %%
Concat_mean/Concat_STD
# Out:
# SP500                         -0.032668
# SOROS FUND MANAGEMENT LLC      0.022452
# PAULSON & CO.INC.             -0.030462
# TIGER GLOBAL MANAGEMENT LLC   -0.007626
# BERKSHIRE HATHAWAY INC         0.039170
# Algo 1                         0.086847
# Algo 2                         0.031583
# dtype: float64

# %%
from googlefinance import getQuotes
import json

# %%
GOOGLEFINANCE("NASDAQ:GOOG", "price", DATE(2014,1,1), DATE(2014,12,31), "DAILY")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-496a1eef1194> in <module>
# ----> 1 GOOGLEFINANCE("NASDAQ:GOOG", "price", DATE(2014,1,1), DATE(2014,12,31), "DAILY")
#
# NameError: name 'GOOGLEFINANCE' is not defined

# %%
Idex_DF.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
Idex_DF=pd.read_csv('IDEX.csv')
Mara_DF=pd.read_csv('MARA.csv')
Riot_DF=pd.read_csv('RIOT.csv')
Ethe_DF=pd.read_csv('ETHE.csv')
Sens_DF=pd.read_csv('SENS.csv')

# %%
Idex_DF.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
Idex_DFC=Idex_DF.rename(columns={'Close':'Idex'})
Mara_DFC=Mara_DF.rename(columns={'Close':'Mara'})
Riot_DFC=Riot_DF.rename(columns={'Close':'Riot'})
Ethe_DFC=Ethe_DF.rename(columns={'Close':'Ethe'})
Sens_DFC=Sens_DF.rename(columns={'Close':'Sens'})

# %%
IdexC=Idex_DFC[['Idex','Date']]
MaraC=Mara_DFC[['Mara','Date']]
RiotC=Riot_DFC[['Riot','Date']]
SensC=Sens_DFC[['Sens','Date']]
EtheC=Ethe_DFC[['Ethe','Date']]

# %%
Idex_DF['Date']=pd.to_datetime(Idex_DF['Date'])
Mara_DF['Date']=pd.to_datetime(Mara_DF['Date'])
Riot_DF['Date']=pd.to_datetime(Riot_DF['Date'])
Ethe_DF['Date']=pd.to_datetime(Ethe_DF['Date'])
Sens_DF['Date']=pd.to_datetime(Sens_DF['Date'])

# %%
Portfolio=[Idex_DF,Mara_DF,Riot_DF,Ethe_DF,Sens_DF]
Portfolio
# Out:
# [           Date  Open  High   Low  Close  Adj Close    Volume
#  0    2020-05-11  0.56  0.56  0.46   0.49       0.49   2859100
#  1    2020-05-12  0.45  0.46  0.42   0.44       0.44   1505500
#  2    2020-05-13  0.44  0.46  0.38   0.40       0.40   1293700
#  3    2020-05-14  0.40  0.42  0.39   0.41       0.41    540500
#  4    2020-05-15  0.44  0.44  0.41   0.43       0.43    604600
#  ..          ...   ...   ...   ...    ...        ...       ...
#  246  2021-05-03  2.98  3.03  2.82   2.83       2.83  11757600
#  247  2021-05-04  2.72  2.74  2.48   2.61       2.61  20999700
#  248  2021-05-05  2.69  2.87  2.64   2.73       2.73  16108400
#  249  2021-05-06  2.74  2.76  2.55   2.66       2.66  13417700
#  250  2021-05-07  2.63  2.74  2.61   2.64       2.64   8645900
#
#  [251 rows x 7 columns],
#             Date       Open       High        Low      Close  Adj Close  \
#  0    2020-05-11   0.800000   0.830000   0.700000   0.760000   0.760000
# ...

# %%
IDMA=pd.merge(IdexC,MaraC,how='inner',on='Date')
IDMR=pd.merge(RiotC,IDMA,how='inner',on='Date')
IMRS=pd.merge(SensC,IDMR,how='inner',on='Date')
Portfolio=pd.merge(EtheC,IMRS,how='inner',on='Date')

# %%
IdexMara=pd.merge(Idex_DF,Mara_DF,how='inner',on='Date')
RiotIDM=pd.merge(Riot_DF,IdexMara,how='inner',on='Date')
EtheRIM=pd.merge(Ethe_DF,RiotIDM,how='inner',on='Date')
Portfolio(broken)=pd.merge(Sens_DF,EtheRIM,how='inner',on='Date')

# %%
Portfolio.plot(x='Date')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Portfolio.columns
# Out:
# Index(['Ethe', 'Date', 'Sens', 'Riot', 'Idex', 'Mara'], dtype='object')

# %%
Portfolio.std()
# Out:
# Ethe     6.601943
# Sens     1.179706
# Riot    19.983221
# Idex     1.141618
# Mara    15.956063
# dtype: float64

# %%
Portfolio.mean()
# Out:
# <ipython-input-313-c25111cd4e9a>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Portfolio.mean()
# Ethe    13.554730
# Sens     1.199462
# Riot    17.205637
# Idex     1.991554
# Mara    13.515777
# dtype: float64

# %%
Portfolio.cov()
# Out:
#            Ethe       Sens        Riot       Idex        Mara
# Ethe  43.585655   4.275268   81.214082   4.146206   68.667248
# Sens   4.275268   1.391706   21.454956   1.118759   16.630941
# Riot  81.214082  21.454956  399.329112  16.988973  311.428105
# Idex   4.146206   1.118759   16.988973   1.303291   14.010785
# Mara  68.667248  16.630941  311.428105  14.010785  254.595944

# %%
Portfolio.isna().sum()
# Out:
# Ethe    0
# Date    0
# Sens    0
# Riot    0
# Idex    0
# Mara    0
# dtype: int64

# %%
Portfolio.var()
# Out:
# Ethe     43.585655
# Sens      1.391706
# Riot    399.329112
# Idex      1.303291
# Mara    254.595944
# dtype: float64

# %% [raw]
# Portfolio.corr()

# %%
Port_corr=Portfolio.corr()

# %%
Port_corr.plot()
# Out:
# <AxesSubplot:>

# %%
Port_STD_21 = Portfolio.rolling(window=21).std()
Port_STD_1Y = Portfolio.rolling(window=100).std()

# %%
Port_STD_21.plot()
# Out:
# <AxesSubplot:>

# %%
weights= [1/5,1/5,1/5,1/5,1/5]
Portfolio
# Out:
#           Ethe       Date   Sens       Riot  Idex       Mara
# 0    11.000000 2020-05-11  0.525   1.590000  0.49   0.760000
# 1    11.433333 2020-05-12  0.528   1.600000  0.44   0.620000
# 2    12.000000 2020-05-13  0.524   1.890000  0.40   0.740000
# 3    11.888889 2020-05-14  0.490   2.280000  0.41   0.860000
# 4    11.111111 2020-05-15  0.479   2.080000  0.43   0.800000
# ..         ...        ...    ...        ...   ...        ...
# 246  32.400002 2021-05-03  2.030  39.990002  2.83  36.220001
# 247  31.959999 2021-05-04  1.950  37.570000  2.61  33.950001
# 248  34.404999 2021-05-05  1.970  36.619999  2.73  33.549999
# 249  34.490002 2021-05-06  1.910  33.450001  2.66  31.400000
# 250  35.070000 2021-05-07  1.890  33.389999  2.64  31.330000
#
# [251 rows x 6 columns]

# %%
Portfolio.plot(kind='bar')
# Out:
# <AxesSubplot:>
